# %%
def vacuum_agent_program(percept0,percept1,percept5):
    """
    Returns an action that maps a percept to an action.
    percept: a tuple (location, status, previous location)
      - location is expected to be 'A' or 'B' or 'C'
      - status is expected to be 'dirty' or something else
    Actions returned: 'Suck', 'Right', 'Left'

    This is a modification of Python code from Russell and Norvig,via copilot.
    Your Goal is to add percept2 to the code below which indicates the direction
    the vacuum arrived in a state and to add another location C. The locations
    are in the order A,B,C for left to right.  Your vacuum does the suck action
    if the status in a state is dirty.  Otherwise, it moves to the next state.
    A->B, B->C, or B->A depending on where the vacuum came from.  In C you go to
    B if the 'room' is clean.

    How many unique states are there now?
    For all unique states after adding room C show the output of the calls to
    vacuum_agent_program.
    )
    """
    if percept1 == 'dirty':
        return 'Suck'

    elif percept0 == 'A':
         return 'Right'

    elif percept0 == 'B':
         if percept5 == 'A':
            return 'Right'

         elif percept5 == 'C':
            return 'Left'

    elif percept0 == 'C':
        return 'Left'




print(vacuum_agent_program('A', 'clean', 'B') )
print(vacuum_agent_program('B', 'clean', 'A') )
print(vacuum_agent_program('B', 'clean', 'C') )
print(vacuum_agent_program('C', 'clean', 'B') )
# Out:
# Right
# Right
# Left
# Left
